# %%
#single line comment
print('Hello Stechies')
'''
Python program to explain multiple line comment
print('Hello')
'''
"""
Python program to explain multiple line comment
print("hello")
"""
print("Hello")
# Out:
# Hello Stechies
# Hello

# %%
#multiple assignments in one line
x,y,z=1,2,3
#unpacking
numbers=(4,5,6)
a,b,c=numbers

# %%
a=5
print("Type of a: ",type(a))
b=5.0
print("\nType of b: ",type(b))
c=2+4j
print("\nType of c: ",type(c))
# Out:
# Type of a:  <class 'int'>
#
# Type of b:  <class 'float'>
#
# Type of c:  <class 'complex'>

# %%
print(type(True))
print(type(False))
print(type(true))
# Out:
# <class 'bool'>
# <class 'bool'>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 print(type(True))
#       2 print(type(False))
# ----> 3 print(type(true))
#
# NameError: name 'true' is not defined

# %%
#take user input using "input" function
name=input("Enter your name: ")
#example of using print() to display a message
print("HEllo, World!")
# Out:
# Enter your name:  tasneem
# HEllo, World!

# %%
#create astring varialble
city_name="City A"
print(f"City Name: {city_name}")
# Out:
# City Name: City A

# %%
temperature =25 
print(f"Temperature: {temperature}°C")
# Out:
# Temperature: 25°C

# %%
carbon_footprint=500.75
print(f"Carbon Footprint: {carbon_footprint} kg CO2")
# Out:
# Carbon Footprint: 500.75 kg CO2

# %%
is_sustainable = carbon_footprint < 400
print(f"Is the city sustainable? {is_sustainable}")
# Out:
# Is the city sustainable? False

# %%
weekly_temperatures=[25,27,28,26,24,30,29]
print(f"Weekly Temperatures: {weekly_temperatures}")
# Out:
# Weekly Temperatures: [25, 27, 28, 26, 24, 30, 29]

# %%
#create a dictionary variable to store city data
city_data = {
    "name": "city A",
    "temperature": 25,
    "is_sustainable": False
}
print(f"City Data: {city_data}")
# Out:
# City Data: {'name': 'city A', 'temperature': 25, 'is_sustainable': False}

# %%
#assign multiple variables at once
city_data, temperature, carbon_footprint = "City B", 30, 350.50
print(f"City Name: {city_data}, Temperature: {temperature}, Carbon Footprint: {carbon_footprint} kg CO2")
# Out:
# City Name: City B, Temperature: 30, Carbon Footprint: 350.5 kg CO2

# %%
number=10
if number>0:
    print(number)
else:
    print("Number is negative:")
# Out:
# 10

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(0,31,3):
    print(i)
# Out:
# 0
# 3
# 6
# 9
# 12
# 15
# 18
# 21
# 24
# 27
# 30

# %%
count=0
while count <5:
    print(count)
    count +=1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
climate_data=[
    {"city": "City A", "temperature": 25, "carbon_footprint": 500},
    {"city": "City B", "temperature": 30, "carbon_footprint": 350},
    {"city": "City C", "temperature": 22, "carbon_footprint": 600},
    {"city": "City D", "temperature": 15, "carbon_footprint": 200},
    {"city": "City E", "temperature": 28, "carbon_footprint": 450},
]
high_temp_threshold=26

high_temp_cities = [city for city in climate_data if city["temperature"] > high_temp_threshold]

print("Cities with high temperatures (>26°C):")
for city in high_temp_cities:
    print(f"{city['city']} - {city['temperature']}°C")
# Out:
# Cities with high temperatures (>26°C):
# City B - 30°C
# City E - 28°C

# %%
total_carbon=0
for city in climate_data:
    total_carbon += city["carbon_footprint"]
average_carbon_footprint = total_carbon / len(climate_data)
print(f"\nAverage Carbon Footprint: {average_carbon_footprint:.2f} kg CO2")
# Out:
# Average Carbon Footprint: 420.00 kg CO2

# %%
sustainabilty_threshold = 400
sustainable_cities = list(filter(lambda city: city["carbon_footprint"] < sustainabilty_threshold, climate_data))
print("\nsustainable cities (carbon footprint < 400 kg CO2):")
for city in sustainable_cities:
    print(f"{city['city']} - {city['carbon_footprint']} kg CO2")
# Out:
# sustainable cities (carbon footprint < 400 kg CO2):
# City B - 350 kg CO2
# City D - 200 kg CO2

# %%
highest_footprint_city=max(climate_data,key=lambda city: city["carbon_footprint"])
print(f"\nCity with highest carbon footprint:")
print(f"{highest_footprint_city['city']} - {highest_footprint_city['carbon_footprint']} kg CO2")
# Out:
# City with highest carbon footprint:
# City C - 600 kg CO2
